# %%
import pandas as pd
import matplotlib.pyplot as plt
col=['state','percent','dollars','pay','region']
payhour = df["pay"].div(df["dollars"].values)
df = pd.read_csv(r'Pay Rate .csv',usecols=col)
df.sort_values(by = 'region')
f = plt.figure()
f.set_figwidth(12)
f.set_figheight(10)
plt.style.use('ggplot')
plt.xlabel("State")
plt.ylabel("Pay Per Hour")
plt.bar(df.region,payhour,width=0.4,color='red' )
plt.scatter(df.region,df.dollars,color='darkblue')
plt.show()
