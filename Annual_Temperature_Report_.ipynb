# %%
import pandas as pd
import matplotlib.pyplot as plt
columns = ["Year","Mean"]
df = pd.read_csv('https://raw.githubusercontent.com/siddheshphatarpekar/Dataset/main/annual_Temperture.csv', usecols=columns)
plt.style.use("fivethirtyeight")
plt.figure(figsize=(12,10))
plt.title("Annual Global Temperature Record")
plt.xlabel("Year")
plt.ylabel("Mean")
plt.plot(df.Year,df.Mean)
plt.show()
